# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauranga2022/Seaborn_tutorial/blob/main/Seaborn_Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planets = sns.load_dataset("planets")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(x="tip",y="total_bill", data= tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill", data=tips, hue="day")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill", data = tips, hue="day", size="size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="day",size="size",palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## Histograms

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips["tip"], bins=20)

# %%
sns.histplot(tips["tip"], kde=True, bins=20) #kde for line
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips["total_bill"], kde = True, bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# total bill is $15 for most of them

# %% [markdown]
# ## distplots

# %%
sns.distplot(tips["total_bill"], kde=True, bins=20)
# Out:
# <ipython-input-23-1842341992cf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde=True, bins=20)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## displots

# %%
sns.displot(tips["total_bill"],kde=True,bins=20)

# %% [markdown]
# ## Barplots

# %%
sns.barplot(x="sex", y="tip", data=tips, palette="YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ##Boxplot

# %%
sns.boxplot(x="day", y ="tip", data=tips, hue ="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y ="total_bill", data=tips, hue ="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Stripplot

# %%
sns.stripplot(x="day", y="tip", data = tips, hue="sex") #sex will not get separated because dodge is not set True
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="tip", data = tips, hue="sex", dodge= True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Jointplots

# %%
sns.jointplot(x="tip", y="total_bill",data=tips, kind="reg") #reg for regression

# %%
sns.jointplot(x="tip", y ="total_bill", kind="kde", data=tips)

# %%
sns.jointplot(x="tip", y ="total_bill", kind="kde", data=tips, shade=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x="tip", y ="total_bill", kind="kde", data=tips, shade=True, cmap="YlGnBu")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x="tip", y ="total_bill", kind="hex", data=tips, cmap="YlGnBu")

# %% [markdown]
# ##Pairplot

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue="pclass")

# %%
import time
x = time.perf_counter()
sns.pairplot(titanic.select_dtypes(['number']), hue="pclass")
y = time.perf_counter()
print(y-x)
# Out:
# 8.650327881000067

# %% [markdown]
# ##Heatmap

# %%
titanic.corr() #we want to look at the correlations among the correlations
# Out:
# <ipython-input-53-2dd75f4bf6fc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr() #we want to look at the correlations among the correlations
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
# ...

# %%
sns.heatmap(titanic.corr(), annot = True, cmap= "YlGnBu") #annot means annotations, values of corr will be printed on the map
# Out:
# <ipython-input-54-f090afe54f49>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot = True, cmap= "YlGnBu")
# <Axes: >

# %%
sns.heatmap(titanic.corr(), annot=True, cmap="coolwarm" ) #colors are relatable
# Out:
# <ipython-input-55-46cf3d259d1f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap="coolwarm" )
# <Axes: >

# %%
sns.heatmap(titanic.corr(), annot=True, cmap="icefire" ) #colors are relatable
# Out:
# <ipython-input-56-5647bbebcc24>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap="icefire" ) #colors are relatable
# <Axes: >

# %% [markdown]
# ## clustermap

# %%
sns.clustermap(iris.drop("species",axis=1))
